# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohawaseem/Task-2/blob/main/week_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install flask-ngrok
# !pip install tensorflow
# !pip install numpy
# !pip install pandas

# %%
# Check the column type and unique values
print(df['label'].dtype)
print(df['label'].unique())
print(df['label'].isnull().sum())

# Define label map
label_map = {'negative':0, 'neutral':1, 'positive':2}

# Convert labels to string first, then lowercase & map
df['label_code'] = df['label'].astype(str).str.lower().map(label_map)

# Drop rows where mapping failed (NaN)
df = df.dropna(subset=['label_code']).reset_index(drop=True)

# Convert to int for training
df['label_code'] = df['label_code'].astype(int)

# Assign y
y = df['label_code'].values
print("Labels ready, shape:", y.shape)
print("Unique labels:", df['label_code'].unique())
# Out:
# float64
# [ 0.  1. nan]
# 584
# Labels ready, shape: (0,)
# Unique labels: []

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Parameters
MAX_WORDS = 10000   # top 10k words
MAX_LEN = 50        # max sequence length

# 1️⃣ Initialize tokenizer
tokenizer = Tokenizer(num_words=MAX_WORDS, oov_token='<OOV>')

# 2️⃣ Fit on cleaned text
df['cleaned'] = df['tweet'].astype(str).apply(lambda x: re.sub(r'http\S+|@\w+|#[A-Za-z0-9_]+|[^A-Za-z0-9\s]', '', x).lower().strip())
tokenizer.fit_on_texts(df['cleaned'])

# 3️⃣ Convert text to sequences
X_seq = tokenizer.texts_to_sequences(df['cleaned'])

# 4️⃣ Pad sequences to ensure same length
X = pad_sequences(X_seq, maxlen=MAX_LEN, padding='post', truncating='post')

# Check shapes
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (0, 50)
# Shape of y: (0,)

# %%
print("Shape of dataset:", df.shape)
print("Columns:", df.columns)
print("Number of NaN in cleaned text:", df['cleaned'].isna().sum())
print("Number of labels after mapping:", df['label_code'].shape)
print("Unique labels:", df['label_code'].unique())
# Out:
# Shape of dataset: (0, 5)
# Columns: Index(['id', 'label', 'tweet', 'cleaned', 'label_code'], dtype='object')
# Number of NaN in cleaned text: 0
# Number of labels after mapping: (0,)
# Unique labels: []

# %%
# Convert to string and map
label_map = {'negative':0, 'neutral':1, 'positive':2}
df['label_code'] = df['label'].astype(str).str.lower().map(label_map)

# Drop NaN labels
df = df.dropna(subset=['label_code']).reset_index(drop=True)

# Convert to int
df['label_code'] = df['label_code'].astype(int)

# Check again
print("Dataset after mapping:", df.shape)
print("Unique labels:", df['label_code'].unique())
# Out:
# Dataset after mapping: (0, 5)
# Unique labels: []

# %%
# Convert to string and map
label_map = {'negative':0, 'neutral':1, 'positive':2}
df['label_code'] = df['label'].astype(str).str.lower().map(label_map)

# Drop NaN labels
df = df.dropna(subset=['label_code']).reset_index(drop=True)

# Convert to int
df['label_code'] = df['label_code'].astype(int)

# Check again
print("Dataset after mapping:", df.shape)
print("Unique labels:", df['label_code'].unique())
# Out:
# Dataset after mapping: (0, 5)
# Unique labels: []

# %%
df['cleaned'] = df['tweet'].astype(str).apply(lambda x: re.sub(r'http\S+|@\w+|#[A-Za-z0-9_]+|[^A-Za-z0-9\s]', '', x).lower().strip())
df = df[df['cleaned'] != '']  # remove empty strings
print("Dataset after removing empty cleaned text:", df.shape)
# Out:
# Dataset after removing empty cleaned text: (0, 5)

# %%
X_texts = df['cleaned'].tolist()
y = df['label_code'].values
print("Number of samples:", len(X_texts))
print("Number of labels:", y.shape[0])
# Out:
# Number of samples: 0
# Number of labels: 0
